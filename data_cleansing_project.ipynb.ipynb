# %% [markdown]
# 🧹 Step 1: Import Libraries

# %%
import pandas as pd

# %% [markdown]
# 📂 Step 2: Create Sample Datasets

# %%
data1 = {
    'Emp_ID': [101, 102, 103, 104, 105],
    'Name': ['Alice', 'Bob', 'Charlie', None, 'Eve'],
    'Department': ['HR', 'IT', None, 'Finance', 'IT'],
    'Salary': [50000, 60000, None, 65000, 62000]
}
df1 = pd.DataFrame(data1)
data2 = {
    'Emp_ID': [101, 102, 103, 106],
    'Project': ['Recruitment', 'App Dev', 'Data Analysis', 'Marketing']
}
df2 = pd.DataFrame(data2)

# %% [markdown]
# 🔍 Step 3: Check for Missing Data

# %%
print(df1.isnull().sum())
# Out:
# Emp_ID        0
# Name          1
# Department    1
# Salary        1
# dtype: int64

# %% [markdown]
# 🧩 Step 4: Fill Missing Data

# %%
df1['Name'].fillna('Unknown', inplace=True)
df1['Department'].fillna(df1['Department'].mode()[0], inplace=True)
df1['Salary'].fillna(df1['Salary'].mean(), inplace=True)

# %% [markdown]
# 🔤 Step 5: String Operations

# %%
df1['Name'] = df1['Name'].str.title()         
df1['Department'] = df1['Department'].str.upper()

# %% [markdown]
# 🔗 Step 6: Merging Data

# %%
inner = pd.merge(df1, df2, on='Emp_ID', how='inner')
left = pd.merge(df1, df2, on='Emp_ID', how='left')
outer = pd.merge(df1, df2, on='Emp_ID', how='outer')

# %% [markdown]
# 📊 Step 7: Data Operations — Aggregation & GroupBy

# %%
avg_salary = df1.groupby('Department')['Salary'].mean().reset_index()
print(avg_salary)
# Out:
#   Department        Salary
# 0    FINANCE  65000.000000
# 1         HR  50000.000000
# 2         IT  60416.666667

# %% [markdown]
# ✅ Step 8: Final Clean Data

# %%
print(df1)
# Out:
#    Emp_ID     Name Department   Salary
# 0     101    Alice         HR  50000.0
# 1     102      Bob         IT  60000.0
# 2     103  Charlie         IT  59250.0
# 3     104  Unknown    FINANCE  65000.0
# 4     105      Eve         IT  62000.0

# %% [markdown]
# 📊 Step 9: Visualization with Matplotlib

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4))
plt.bar(avg_salary['Department'], avg_salary['Salary'])
plt.title('Average Salary by Department')
plt.xlabel('Department')
plt.ylabel('Average Salary (₹)')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
